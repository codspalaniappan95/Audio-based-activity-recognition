# %%
import librosa
import librosa.display
import os
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
hair,sr = librosa.load('hair1.wav')

# %%
plt.figure(figsize=(12,4))
librosa.display.waveplot(hair,sr=sr)

# %%
type_data,sr = librosa.load('test1.wav')
plt.figure(figsize=(12,4))
librosa.display.waveplot(type_data,sr=sr)

# %%
laund_data,sr = librosa.load('laund1.wav')
plt.figure(figsize=(12,4))
librosa.display.waveplot(laund_data,sr=sr)
